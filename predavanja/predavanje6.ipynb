# %%
import time

# %%
time.time()
# Out:
# 1764155058.160717

# %%
zdaj = time.time()

# %%
time.time() - zdaj
# Out:
# 9.952604055404663

# %%
time.localtime()
# Out:
# time.struct_time(tm_year=2025, tm_mon=11, tm_mday=26, tm_hour=12, tm_min=5, tm_sec=7, tm_wday=2, tm_yday=330, tm_isdst=0)

# %%
time.gmtime()
# Out:
# time.struct_time(tm_year=2025, tm_mon=11, tm_mday=26, tm_hour=11, tm_min=5, tm_sec=55, tm_wday=2, tm_yday=330, tm_isdst=0)

# %%
import locale

# %%
locale.setlocale(locale.LC_ALL, "de_DE")
# Out:
# 'de_DE'

# %%
time.strftime("Danes je %A, %d. %B %Y, ura pa je %H:%M:%S", zdaj)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 time.strftime("Danes je %A, %d. %B %Y, ura pa je %H:%M:%S", zdaj)
#
# TypeError: Tuple or struct_time argument required
